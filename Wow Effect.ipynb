# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os
from collections import Counter
# %matplotlib inline
from decimal import Decimal
import sklearn
from sklearn import linear_model, metrics, preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import r2_score, f1_score
from pandas.plotting import table
pd.options.display.float_format = "{:,.0f}".format
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("TotalDF1.csv")
df
# Out:
#                   Player  Overall Score  Potential Score  Market Value  \
# 0           Lionel Messi             94               97    78,000,000
# 1      Cristiano Ronaldo             92               92    55,500,000
# 2            Luis Suárez             89               89           nan
# 3                 Falcao             89               89           nan
# 4                 Falcao             89               89           nan
# ...                  ...            ...              ...           ...
# 12683      Matthieu Udol             68               75     1,100,000
# 12684     Felix Passlack             68               78     1,400,000
# 12685     Andrea Favilli             68               78     1,500,000
# 12686    Hidde ter Avest             68               76     1,200,000
# 12687       Oliver Burke             68               73     1,200,000
#
#        Weekly Salary  Height  Weight  Age Preferred Foot    id  \
# ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(keep='first', inplace=True)
df.drop(axis = 1, columns=['player_name'], inplace=True)
df['Preferred Foot'].replace({"Right": 0, "Left": 1}, inplace=True)

# %%
df = df.loc[df.year == 2020]
#df = df.loc[df['Preferred Foot'] == 'Right']
df = df.loc[(df['Age'] >= 24) & (df['Age'] <= 29)]
df = df.loc[df['goals'] >= 9]
df = df.loc[df['goals'] >= 10]
df = df.loc[(df['Market Value'] <= 25000000)]
df = df.loc[(df['Weekly Salary'] <= 70000)]

# %%
df
# Out:
#                 Player  Overall Score  Potential Score  Market Value  \
# 11193    Gerard Moreno             82               82    23,500,000
# 11234    Wout Weghorst             81               81    19,500,000
# 11340      Luis Muriel             80               80    15,500,000
# 11457      Andy Delort             79               79    13,500,000
# 11501      André Silva             78               83    14,000,000
# 11579       João Pedro             78               78    11,000,000
# 11669  Ludovic Ajorque             77               80    11,500,000
# 12409  Patrick Bamford             72               75     4,000,000
#
#        Weekly Salary  Height  Weight  Age Preferred Foot    id  games  time  \
# 11193         49,000     180      77   28           Left  2120     16  1419
# 11234         60,000     197      84   28          Right  7052     16  1362
# 11340         70,000     179      79   29          Right  1229     15   480
# ...

# %%
df.nlargest(10,['xGChain', 'goals'])
# Out:
#                 Player  Overall Score  Potential Score   Market Value  \
# 12409  Patrick Bamford             72               75  4,000,000.000
# 11193    Gerard Moreno             82               82 23,500,000.000
# 11501      André Silva             78               83 14,000,000.000
# 11234    Wout Weghorst             81               81 19,500,000.000
# 11457      Andy Delort             79               79 13,500,000.000
# 11340      Luis Muriel             80               80 15,500,000.000
# 11669  Ludovic Ajorque             77               80 11,500,000.000
# 11579       João Pedro             78               78 11,000,000.000
#
#        Weekly Salary  Height  Weight  Age Preferred Foot    id  games  time  \
# 12409     43,000.000     185      71   27           Left   822     18  1556
# 11193     49,000.000     180      77   28           Left  2120     16  1419
# 11501     38,000.000     184      78   24          Right  6170     15  1285
# ...

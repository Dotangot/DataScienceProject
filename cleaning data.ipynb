# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("TotalDF1.csv")

# %%
df.sort_values(["Player"])
# Out:
#                 Player  Overall Score  Potential Score  Market Value  \
# 4824   Aaron Cresswell             74               76     3300000.0
# 10135  Aaron Cresswell             76               76     6000000.0
# 8603   Aaron Cresswell             74               75     5500000.0
# 11883  Aaron Cresswell             76               76     6500000.0
# 1476   Aaron Cresswell             70               79           NaN
# ...                ...            ...              ...           ...
# 3787    Özkan Yildirim             66               76      675000.0
# 1728    Özkan Yildirim             67               77      675000.0
# 10720     Ørjan Nyland             72               72     2100000.0
# 5010      Ørjan Nyland             73               75           NaN
# 2908      Ørjan Nyland             73               81     2100000.0
#
#        Weekly Salary  Height  Weight  Age Preferred Foot    id  ...  \
# 4824         35000.0     170      66   26           Left   534  ...
# ...

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12683    False
# 12684    False
# 12685    False
# 12686    False
# 12687    False
# Length: 12688, dtype: bool

# %%
df.shape
# Out:
# (12688, 28)

# %%
df.drop_duplicates(keep='first', inplace=True)
df.shape
# Out:
# (12419, 28)

# %%
df.drop(axis = 1, columns=['player_name', 'team_title', 'position'], inplace=True)
df['Preferred Foot'].replace({"Right": 0, "Left": 1}, inplace=True)

# %%
df.dropna(inplace=True)
df.sort_values("Market Value", ascending=False)
# Out:
#                  Player  Overall Score  Potential Score  Market Value  \
# 7389             Neymar             92               93   119500000.0
# 7387       Lionel Messi             94               94   118500000.0
# 9197       Lionel Messi             94               94   110500000.0
# 5600             Neymar             92               94   106000000.0
# 7392    Kevin De Bruyne             91               92   104500000.0
# ...                 ...            ...              ...           ...
# 11165  Gianluigi Buffon             83               83        1000.0
# 6130             Hilton             79               79        1000.0
# 6569     Gareth McAuley             76               76        1000.0
# 9267   Gianluigi Buffon             86               86        1000.0
# 12314         Cifuentes             73               73        1000.0
#
#        Weekly Salary  Height  Weight  Age  Preferred Foot    id  games  time  \
# ...

# %%
df.to_csv(r'C:\Users\user\project\FinalDF.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11207 entries, 0 to 12687
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player           11207 non-null  object
#  1   Overall Score    11207 non-null  int64
#  2   Potential Score  11207 non-null  int64
#  3   Market Value     11207 non-null  float64
#  4   Weekly Salary    11207 non-null  float64
#  5   Height           11207 non-null  int64
#  6   Weight           11207 non-null  int64
#  7   Age              11207 non-null  int64
#  8   Preferred Foot   11207 non-null  int64
#  9   id               11207 non-null  int64
#  10  games            11207 non-null  int64
#  11  time             11207 non-null  int64
#  12  goals            11207 non-null  int64
#  13  xG               11207 non-null  float64
#  14  assists          11207 non-null  int64
#  15  xA               11207 non-null  float64
#  16  shots            11207 non-null  int64
# ...

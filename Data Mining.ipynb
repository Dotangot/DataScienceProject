# %%
import os
import sys
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import asyncio
import json
import aiohttp
from understat import Understat

# %%
#explanation

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa14/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1

fifa14df = pd.DataFrame(player_list)
fifa14df.to_csv(r'C:\Users\user\project\fifa14.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2014)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2014
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2014.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa15/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1
    
fifa15df = pd.DataFrame(player_list)
fifa15df.to_csv(r'C:\Users\user\project\fifa15.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2015)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2015
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2015.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa16/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1
    
fifa16df = pd.DataFrame(player_list)
fifa16df.to_csv(r'C:\Users\user\project\fifa16.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2016)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2016
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2016.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa17/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1
    
fifa17df = pd.DataFrame(player_list)
fifa17df.to_csv(r'C:\Users\user\project\fifa17.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2017)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2017
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2017.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa18/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1
    
fifa18df = pd.DataFrame(player_list)
fifa18df.to_csv(r'C:\Users\user\project\fifa18.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2018)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2018
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2018.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa19/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1
    
fifa19df = pd.DataFrame(player_list)
fifa19df.to_csv(r'C:\Users\user\project\fifa19.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2019)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2019
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2019.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
player_list = []
url = 'https://www.fifaindex.com/players/fifa20/{}/'   #creating url for primary pages

pageno = 1
while (pageno<250)
    webpage = url.format(pageno)
    response1 = requests.get(webpage)
    if response1.status_code != 200:   # if maximum page exceeded, break out of loop
        break
    mainpage = response1.text
    mainsoup = BeautifulSoup(mainpage,'lxml')   # turn primary page into soup
    for tag in mainsoup.find_all('td',attrs={'data-title':'Name'}):   #iterate through each player on primary pages
        
        webpage2 = 'https://www.fifaindex.com'+str(tag.find('a')['href'])   #link for secondary pages
        response2 = requests.get(webpage2)
        subpage = response2.text
        soup = BeautifulSoup(subpage,'lxml')     # turn secondary page into soup
                                                   
        Player = soup.find_all('h5', class_='card-header')[0].contents[0]  

        Overall_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[0].text  
        Potential_Score = soup.find_all('h5', class_='card-header')[0].contents[1].contents[-1].text    
        if soup.find_all('p', class_='data-currency data-currency-euro'):
            Market_Value = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[0].findNext().text if i.isdigit()])
            Weekly_Salary = ''.join([i for i in soup.find_all('p', class_='data-currency data-currency-euro')[1].findNext().text if i.isdigit()])
        else:
            Market_Value = np.nan
            Weekly_Salary = np.nan
        Height = soup.find_all('span', class_="data-units data-units-metric")[0].text.split()[0]   
        Weight = soup.find_all('span', class_="data-units data-units-metric")[1].text.split()[0]   
        Age = soup.find(text='Age ').findNext().text
        Preferred_Foot = soup.find(text='Preferred Foot ').findNext().text

        
        player = {'Player':Player,'Overall Score':Overall_Score,'Potential Score':Potential_Score,'Market Value':Market_Value,
                 'Weekly Salary':Weekly_Salary,'Height':Height,'Weight':Weight,'Age':Age,'Preferred Foot':Preferred_Foot}  
        player_list.append(player)    
    
    print(pageno)
    pageno += 1
    
fifa20df = pd.DataFrame(player_list)
fifa20df.to_csv(r'C:\Users\user\project\fifa20.csv', index=False)

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        df = pd.DataFrame()
        leagues = ["epl", "La liga", "Bundesliga", "Serie A", "Ligue 1"]
        for league in leagues:
            player = await understat.get_league_players(league, 2020)
            curr_df = pd.DataFrame(player)
            curr_df['year'] = 2020
            df = df.append(curr_df)
        df.to_csv(r'C:\Users\user\project\understat_2020.csv', index=False)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())

# %%
fifa14 = pd.read_csv("fifa14.csv")
understat14 = pd.read_csv("understat_2014.csv")
dfinal = fifa14.merge(understat14, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2014.csv', index=False)

fifa15 = pd.read_csv("fifa15.csv")
understat15 = pd.read_csv("understat_2015.csv")
dfinal = fifa15.merge(understat15, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2015.csv', index=False)

fifa16 = pd.read_csv("fifa16.csv")
understat16 = pd.read_csv("understat_2016.csv")
dfinal = fifa16.merge(understat16, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2016.csv', index=False)

fifa17 = pd.read_csv("fifa17.csv")
understat17 = pd.read_csv("understat_2017.csv")
dfinal = fifa17.merge(understat17, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2017.csv', index=False)

fifa18 = pd.read_csv("fifa18.csv")
understat18 = pd.read_csv("understat_2018.csv")
dfinal = fifa18.merge(understat18, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2018.csv', index=False)

fifa19 = pd.read_csv("fifa19.csv")
understat19 = pd.read_csv("understat_2019.csv")
dfinal = fifa19.merge(understat19, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2019.csv', index=False)

fifa20 = pd.read_csv("fifa20.csv")
understat20 = pd.read_csv("understat_2020.csv")
dfinal = fifa20.merge(understat20, how='inner',  left_on='Player', right_on='player_name')
dfinal.to_csv(r'C:\Users\user\project\df2020.csv', index=False)

#example of 2020 final merged dataframe
dfinal
# Out:
#                  Player  Overall Score  Potential Score  Market Value  \
# 0          Lionel Messi             94               94    95500000.0
# 1     Cristiano Ronaldo             93               93    58500000.0
# 2       Virgil van Dijk             91               92    90000000.0
# 3             Jan Oblak             91               93    77500000.0
# 4       Kevin De Bruyne             91               91    90000000.0
# ...                 ...            ...              ...           ...
# 1687      Matthieu Udol             68               75     1100000.0
# 1688     Felix Passlack             68               78     1400000.0
# 1689     Andrea Favilli             68               78     1500000.0
# 1690    Hidde ter Avest             68               76     1200000.0
# 1691       Oliver Burke             68               73     1200000.0
#
#       Weekly Salary  Height  Weight  Age Preferred Foot    id  ... key_passes  \
# 0          560000.0     170      72   33           Left  2097  ...         35
# 1          400000.0     187      83   35          Right  2371  ...         20
# 2          245000.0     193      92   29          Right   833  ...          0
# 3          125000.0     188      87   27          Right  2261  ...          0
# 4          370000.0     181      70   29          Right   447  ...         50
# ...             ...     ...     ...  ...            ...   ...  ...        ...
# 1687         5900.0     178      68   24           Left  5745  ...         10
# 1688        17000.0     170      74   22          Right  2663  ...          3
# 1689         6500.0     191      78   23           Left  1997  ...          2
# 1690         5300.0     182      78   23          Right  7000  ...          0
# 1691        15500.0     188      82   23          Right  5256  ...         13
#
#       yellow_cards  red_cards  position         team_title  npg       npxG  \
# 0                3          0     F M S          Barcelona    9  10.525126
# 1                0          0       F S           Juventus   11   8.615108
# 2                1          0         D          Liverpool    1   0.553383
# 3                0          0        GK    Atletico Madrid    0   0.000000
# 4                1          0       M S    Manchester City    1   5.595282
# ...            ...        ...       ...                ...  ...        ...
# 1687             1          1       D S               Metz    0   0.063979
# 1688             0          0       D S  Borussia Dortmund    1   0.510328
# 1689             1          0       F S             Verona    2   1.872083
# 1690             0          0       D S            Udinese    0   0.000000
# 1691             2          0       F S   Sheffield United    0   1.377128
#
#         xGChain  xGBuildup  year
# 0     16.700625   9.952490  2020
# 1     11.429511   2.749727  2020
# 2      1.409594   1.288435  2020
# 3      2.043462   2.043462  2020
# 4     15.087370   7.786592  2020
# ...         ...        ...   ...
# 1687   2.182267   0.692643  2020
# 1688   1.801331   1.050860  2020
# 1689   2.520636   0.638041  2020
# 1690   1.647105   1.647105  2020
# 1691   4.340086   0.500298  2020
#
# [1692 rows x 28 columns]

# %%
df14 = pd.read_csv("df14.csv")
df15 = pd.read_csv("df15.csv")
df16 = pd.read_csv("df16.csv")
df17 = pd.read_csv("df2017.csv")
df18 = pd.read_csv("df2018.csv")
df19 = pd.read_csv("df2019.csv")
df20 = pd.read_csv("df2020.csv")
totalDf = pd.concat([df14, df15, df16, df17, df18, df19, df20], ignore_index=True)

# %%
totalDf
# Out:
#                   Player  Overall Score  Potential Score  Market Value  \
# 0           Lionel Messi             94               97    78000000.0
# 1      Cristiano Ronaldo             92               92    55500000.0
# 2            Luis Suárez             89               89           NaN
# 3                 Falcao             89               89           NaN
# 4                 Falcao             89               89           NaN
# ...                  ...            ...              ...           ...
# 12868      Matthieu Udol             68               75     1100000.0
# 12869     Felix Passlack             68               78     1400000.0
# 12870     Andrea Favilli             68               78     1500000.0
# 12871    Hidde ter Avest             68               76     1200000.0
# 12872       Oliver Burke             68               73     1200000.0
#
#        Weekly Salary  Height  Weight  Age Preferred Foot    id  ...  \
# 0           450000.0     169      67   27           Left  2097  ...
# 1           325000.0     185      80   29          Right  2371  ...
# 2                NaN     181      81   27          Right  2098  ...
# 3                NaN     176      75   28          Right   696  ...
# 4                NaN     176      75   28          Right   696  ...
# ...              ...     ...     ...  ...            ...   ...  ...
# 12868         5900.0     178      68   24           Left  5745  ...
# 12869        17000.0     170      74   22          Right  2663  ...
# 12870         6500.0     191      78   23           Left  1997  ...
# 12871         5300.0     182      78   23          Right  7000  ...
# 12872        15500.0     188      82   23          Right  5256  ...
#
#       key_passes  yellow_cards  red_cards  position         team_title  npg  \
# 0             95             4          0       F S          Barcelona   38
# 1             76             5          1       F M        Real Madrid   38
# 2             60             4          0       F S          Barcelona   16
# 3             18             2          0       F S  Manchester United    4
# 4              0             0          0       F S             Monaco    1
# ...          ...           ...        ...       ...                ...  ...
# 12868         10             1          1       D S               Metz    0
# 12869          3             0          0       D S  Borussia Dortmund    1
# 12870          2             1          0       F S             Verona    2
# 12871          0             0          0       D S            Udinese    0
# 12872         13             2          0       F S   Sheffield United    0
#
#             npxG    xGChain  xGBuildup  year
# 0      31.432098  54.753610  19.756724  2014
# 1      30.389686  43.608020   7.520237  2014
# 2      14.542310  28.306160   6.215008  2014
# 3       7.156320   9.530347   2.632779  2014
# 4       0.492151   0.640225   0.148074  2014
# ...          ...        ...        ...   ...
# 12868   0.063979   2.182267   0.692643  2020
# 12869   0.510328   1.801331   1.050860  2020
# 12870   1.872083   2.520636   0.638041  2020
# 12871   0.000000   1.647105   1.647105  2020
# 12872   1.377128   4.340086   0.500298  2020
#
# [12873 rows x 28 columns]

# %%
totalDf.to_csv(r'C:\Users\user\project\TotalDF.csv', index=False)
